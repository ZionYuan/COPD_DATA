# %%
import pandas as  pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from pylab import mpl
from matplotlib.backends.backend_pdf import PdfPages

mpl.rcParams['axes.unicode_minus']=False #用来正常显示负号
mpl.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

t = list(os.walk('D:\\Study\\COPD\\COPD_DATA\\olds_modification'))[0][2]
t.sort()

dictt={}
tw=[]
hxl=[]
ml=[]
xyd=[]
xyg=[]
xybhd=[]
for fname in t[1:]:
            #print(fname)
            df = pd.read_csv('D:\\Study\\COPD\\COPD_DATA\\olds_modification\\'+fname
                            ,engine='python'
                            ,encoding='utf8'
                            ,index_col='date'
                            ,usecols = [0,1,3,5,6,7,8])
            df.dropna(axis=0, how='any', inplace=True)
            s = df.var()
            
            dictt[fname]=s[5]
            
            tw.append(s[0])
            hxl.append(s[1])
            ml.append(s[2])
            xyd.append(s[3])
            xyg.append(s[4])
            xybhd.append(s[5])
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 150 #分辨率
plt.figure(21,figsize = (20,30))

ax1 = plt.subplot(611)
ax1.set_title('体温')
plt.plot(tw,label='方差')
plt.legend()
ax2 = plt.subplot(612)
plt.plot(hxl,label='方差')
ax2.set_title('呼吸率')
plt.legend()
ax3 = plt.subplot(613)
plt.plot(ml,label='方差')
ax3.set_title('脉率')
plt.legend()
ax4 = plt.subplot(614)
plt.plot(xyd,label='方差')
ax4.set_title('血压(低)')
plt.legend()
ax5 = plt.subplot(615)
plt.plot(xyg,label='方差')
ax5.set_title('血压(高)')
plt.legend()
ax6 = plt.subplot(616)
plt.plot(xybhd,label='方差')
ax6.set_title('血氧饱和度')

plt.figsize=(20,10)
plt.legend()
plt.savefig('D:\\Study\\COPD\\COPD_DATA\\var.png')
plt.show()

# %%
print(max(dictt,key=dictt.get))
# Out:
# 55818.csv

# %%
fname = '56391.csv'
df2 = pd.read_csv('/Users/yuanzi/学习/yz/COPD/COPD_DATA/olds_modification/'+fname
                            ,engine='python'
                            ,encoding='utf8'
                            ,index_col='date'
                            ,usecols = [0,1,3,5,6,7,8])
df2.dropna(axis=0, how='any', inplace=True)
print(df2.var())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-fc70957f3df7> in <module>
#       4                             ,encoding='utf8'
#       5                             ,index_col='date'
# ----> 6                             ,usecols = [0,1,3,5,6,7,8])
#       7 df2.dropna(axis=0, how='any', inplace=True)
#       8 print(df2.var())
#
# ...

# %%
fname = '56342.csv'
df2 = pd.read_csv('/Users/yuanzi/学习/yz/COPD/COPD_DATA/olds_modification/'+fname
                            ,engine='python'
                            ,encoding='utf8'
                            ,index_col='date'
                            ,usecols = [0,1,3,5,6,7,8])
df2.dropna(axis=0, how='any', inplace=True)
print(df2.var())
# Out:
# 体温         2.013361
# 呼吸率        4.327686
# 脉率        64.064050
# 血压(低)     75.955785
# 血压(高)    155.935399
# 血氧饱和度     24.218320
# dtype: float64

# %%
import pandas as  pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from pylab import mpl
from matplotlib.backends.backend_pdf import PdfPages

mpl.rcParams['axes.unicode_minus']=False #用来正常显示负号
mpl.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

t = list(os.walk('D:\\Study\\COPD\\COPD_DATA\\olds_modification'))[0][2]
t.sort()

dictt={}
tw=[]
hxl=[]
ml=[]
xyd=[]
xyg=[]
xybhd=[]

dicttv={}
twv=[]
hxlv=[]
mlv=[]
xydv=[]
xygv=[]
xybhdv=[]
for fname in t[1:]:
            #print(fname)
            df = pd.read_csv('D:\\Study\\COPD\\COPD_DATA\\olds_modification\\'+fname
                            ,engine='python'
                            ,encoding='utf8'
                            ,index_col='date'
                            ,usecols = [0,1,3,5,6,7,8])
            df.dropna(axis=0, how='any', inplace=True)
            s = df.mean()
            v = df.var()
            
            #dictt[fname]=s[5]
            
            tw.append(s[0])
            hxl.append(s[1])
            ml.append(s[2])
            xyd.append(s[3])
            xyg.append(s[4])
            xybhd.append(s[5])
            
            twv.append(s[0])
            hxlv.append(s[1])
            mlv.append(s[2])
            xydv.append(s[3])
            xygv.append(s[4])
            xybhdv.append(s[5])
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 150 #分辨率
plt.figure(21,figsize = (20,30))

x_axis = range(0, len(ml))

ax1 = plt.subplot(611)
ax1.set_title('体温')
plt.plot(x_axis,tw,label='均值')
#plt.plot(x_axis,twv,label='方差',color = 'blue')
plt.legend()

ax2 = plt.subplot(612)
plt.plot(hxl,label='均值')

ax2.set_title('呼吸率')
plt.legend()

ax3 = plt.subplot(613)
plt.plot(ml,label='均值')

ax3.set_title('脉率')
plt.legend()

ax4 = plt.subplot(614)
plt.plot(xyd,label='均值')

ax4.set_title('血压(低)')
plt.legend()

ax5 = plt.subplot(615)
plt.plot(xyg,label='均值')

ax5.set_title('血压(高)')
plt.legend()

ax6 = plt.subplot(616)
plt.plot(xybhd,label='均值')

ax6.set_title('血氧饱和度')
plt.legend()

plt.figsize=(20,10)
plt.savefig('D:\\Study\\COPD\\COPD_DATA\\mean.png')
plt.show()

# %%
x=range(len(xybhd))

# %%
x
# Out:
# range(0, 251)
