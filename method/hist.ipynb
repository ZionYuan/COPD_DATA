# %%
import numpy as np
import pandas as  pd
import matplotlib
import matplotlib.pyplot as plt
import os 
t = list(os.walk('/Users/yuanzi/学习/yz/COPD/COPD_DATA/olds_modification'))[0][2]
count = 0
ln=[]

feature = '脉率'#手动更改,一个一个看
for fname in t:
    try:
        df = pd.read_csv('/Users/yuanzi/学习/yz/COPD/COPD_DATA/olds_modification/'+fname)
        arr = plt.hist(df[feature])
        if np.sum(arr[0]==0) >=5:#可能存在偏移量较大的值,5 这个值可以变,可以多尝试,6,7,8都可以
            print(fname)
            print(arr)
            df.plot(x='date',y=feature,title=fname,figsize=(20,10))
            plt.show()
    except Exception:
        print(fname)
# Out:
# 46971.csv
# (array([ 1.,  0.,  0.,  0.,  0.,  0., 26., 53., 34.,  8.]), array([18. , 24.3, 30.6, 36.9, 43.2, 49.5, 55.8, 62.1, 68.4, 74.7, 81. ]), <a list of 10 Patch objects>)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 33033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 29575 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 33033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 29575 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 55717.csv
# ...

# %%
#脉率 存在低于 40 的 是否异常?
