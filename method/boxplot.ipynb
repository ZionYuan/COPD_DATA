# %%
'''
@Description:
@Author: YuanZi
@Github: https://github.com/yzmean
@Date: 2019-07-04 14:46:55
@LastEditTime: 2019-07-04 20:34:58
'''

import pandas as  pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import os 
t = list(os.walk('/Users/yuanzi/学习/yz/COPD/COPD_DATA/olds_best'))[0][2]
count = 0
ln=[]
feature = '体温'
for name in t:
    if os.path.getsize('/Users/yuanzi/学习/yz/COPD/COPD_DATA/olds_best/'+name)>5000:#100条左右数据量
        count+=1
        ln.append(name)
for fname in ln:
    df = pd.read_csv('/Users/yuanzi/学习/yz/COPD/COPD_DATA/olds_best/'+fname)
    bp = df.boxplot(column=feature,return_type='dict',figsize=(10,8))
    ycz_tmp = bp['fliers'][0].get_ydata()
    ycz=[]
    for y in ycz_tmp:
        if y>450 or y<300:
            ycz.append(y)
#     print(fname+':')
#     print(ycz)
    
#     df.plot(x='date',y=feature,figsize=(20,8),title=fname)
# Out:
# 48545.csv:
# []
# 47892.csv:
# []
# 56021.csv:
# []
# 46971.csv:
# []
# 26920.csv:
# []
# 48747.csv:
# []
# 46811.csv:
# []
# 48814.csv:
# []
# 55662.csv:
# []
# 56342.csv:
# []
# 55663.csv:
# []
# 48815.csv:
# []
# 48801.csv:
# []
# 44626.csv:
# []
# 26921.csv:
# []
# 55717.csv:
# []
# 48791.csv:
# [34.0]
# 47139.csv:
# []
# 48544.csv:
# []
# 44624.csv:
# []
# 48156.csv:
# []
# 55675.csv:
# []
# 26314.csv:
# []
# 46351.csv:
# []
# 26315.csv:
# [50.0]
# 47927.csv:
# []
# 55890.csv:
# []
# 48625.csv:
# []
# 55847.csv:
# []
# 44631.csv:
# []
# 30629.csv:
# []
# 46973.csv:
# []
# 47884.csv:
# []
# 26261.csv:
# []
# 47880.csv:
# []
# 47328.csv:
# [34.0]
# 28089.csv:
# []
# 44635.csv:
# [3650.0]
# 55738.csv:
# []
# 56351.csv:
# []
# 48635.csv:
# []
# 47506.csv:
# []
# 47089.csv:
# []
# 48387.csv:
# []
# 55659.csv:
# []
# 48807.csv:
# []
# 44634.csv:
# []
# 44636.csv:
# []
# 55713.csv:
# []
# 46828.csv:
# []
# 56391.csv:
# []
# 46814.csv:
# []
# 48839.csv:
# []
# 48622.csv:
# []
# ...

# %%
asx = 11
if asx > 15 or asx < 10:
    print('yes')
else:
    print('no')
# Out:
# no
